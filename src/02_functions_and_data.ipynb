# %% [markdown]
# # Notebook 2 — Form Calculations and Training Data Preparation
#
# Here we calculate the **form** of any team over their last N matches.
#
# **Definition of form:** the net ELO change a team accumulated over their last N matches, using FIFA's SUM formula for each game:
#
# $$\text{form} = \sum_{i=1}^{N} I_i \times (W_i - W_{e,i})$$
#
# - $I$ — match importance weight (same scale as FIFA's official algorithm)
# - $W$ — actual result: 1 (win), 0.5 (draw), 0 (loss)
# - $W_e$ — expected result based on ELO difference between teams at the time of the match
#
# A **positive** form score means the team consistently beat expectations. A **negative** score means they underperformed.
#
# We walk the last N matches forward using the team's current FIFA ELO as the starting point, so the baseline is always grounded in the official present-day rating.

# %% [markdown]
# ---
# ## 1. Imports & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

OUTPUT_DIR = Path('output')
MODEL_OUTPUT_DIR = Path('model_data')

results  = pd.read_csv(OUTPUT_DIR / 'results_clean.csv', parse_dates=['date'])
recent_elo   = pd.read_csv(OUTPUT_DIR / 'recent_elo_clean.csv', parse_dates=['date'])
hist_elo = pd.read_csv(OUTPUT_DIR / 'historical_elo_clean.csv', parse_dates=['date'])

# Flat lookup for the 48 WC2026 teams — used as the default ELO baseline
ELO_LOOKUP = dict(zip(recent_elo['team'], recent_elo['rating']))

# Pre-index historical ELO by team for fast date-aware lookups
HIST_ELO_INDEX = {
    team: grp.sort_values('date').reset_index(drop=True)
    for team, grp in hist_elo.groupby('team')
}

# Pre-index matches by team so get_form doesn't scan the full DataFrame each call
TEAM_MATCHES = {}
for team, group in pd.concat([
    results.assign(_team=results['home_team']),
    results.assign(_team=results['away_team'])
]).groupby('_team'):
    TEAM_MATCHES[team] = group.drop(columns='_team').sort_values('date').reset_index(drop=True)

print(f'Matches loaded       : {len(results):,}')
print(f'Teams indexed        : {len(TEAM_MATCHES)}')
print(f'WC2026 ELO lookup    : {len(ELO_LOOKUP)} teams')
print(f'Historical ELO index : {len(HIST_ELO_INDEX)} teams')
# Out:
# Matches loaded       : 49,378
# Teams indexed        : 336
# WC2026 ELO lookup    : 243 teams
# Historical ELO index : 264 teams

# %% [markdown]
# ---
# ## 2. Tournament Importance Weights
#
# FIFA weights each match by its competitive importance (I). We use the same scale here so that form earned in a World Cup match counts more than a friendly.
#
# Tournaments not in this map (obscure regional cups, etc.) fall back to `1.0`.

# %%
TOURNAMENT_WEIGHTS = {
    # Friendlies
    'Friendly':                               1.0,
    'FIFA Series':                            1.0,
    # Nations Leagues
    'UEFA Nations League':                    1.5,
    'CONCACAF Nations League':                1.5,
    'CONCACAF Nations League qualification':  1.5,
    # Qualification
    'FIFA World Cup qualification':           2.5,
    'UEFA Euro qualification':                2.5,
    'African Cup of Nations qualification':   2.5,
    'AFC Asian Cup qualification':            2.5,
    'Gold Cup qualification':                 2.5,
    'Oceania Nations Cup qualification':      2.5,
    'CONCACAF Championship qualification':    2.5,
    'Copa América qualification':             2.5,
    'AFF Championship qualification':         2.5,
    'EAFF Championship qualification':        2.5,
    'AFC Challenge Cup qualification':        2.5,
    # Confederation finals
    'UEFA Euro':                              3.5,
    'Copa América':                           3.5,
    'African Cup of Nations':                 3.5,
    'AFC Asian Cup':                          3.5,
    'Gold Cup':                               3.5,
    'CONCACAF Championship':                  3.5,
    'Oceania Nations Cup':                    3.5,
    'AFF Championship':                       3.5,
    'WAFF Championship':                      3.5,
    'SAFF Cup':                               3.5,
    'Gulf Cup':                               3.5,
    'Arab Cup':                               3.5,
    'COSAFA Cup':                             3.5,
    'CECAFA Cup':                             3.5,
    # Confederations Cup
    'Confederations Cup':                     4.0,
    # World Cup
    'FIFA World Cup':                         5.0,
}

# Tournaments we consider "competitive" (no friendlies)
FRIENDLY_TOURNAMENTS = {'Friendly', 'FIFA Series'}

results['importance'] = results['tournament'].map(TOURNAMENT_WEIGHTS).fillna(1.0)
results['is_competitive'] = ~results['tournament'].isin(FRIENDLY_TOURNAMENTS)

print('Competitive matches:', results['is_competitive'].sum())
print('Friendly matches:   ', (~results['is_competitive']).sum())
# Out:
# Competitive matches: 30953
# Friendly matches:    18425

# %% [markdown]
# ---
# ## 3. Finding a Team's Form
#
# Form is the sum of `I × (W − Wₑ)` across the last N matches, where both teams' current FIFA ELO is used as a fixed baseline for every match. This is a simplification made to not overcomplicate or backtrack unnecessarily when the estimation is close enough.

# %%
FRIENDLY_TOURNAMENTS = {'Friendly', 'FIFA Series'}

def expected_result(rating_a: float, rating_b: float) -> float:
    return 1 / (10 ** (-(rating_a - rating_b) / 600) + 1)


def get_elo_at_date(team: str, as_of: pd.Timestamp) -> float:
    """
    Return the most recent ELO rating for a team on or before a given date,
    using the historical ELO index. Falls back to 1000 if no data is found.
    """
    team_hist = HIST_ELO_INDEX.get(team)
    if team_hist is None:
        return 1000.0
    past = team_hist[team_hist['date'] <= as_of]
    if past.empty:
        return 1000.0
    return past.iloc[-1]['rating']


def get_form(team: str, n: int = 10, competitive: bool = False,
             as_of: pd.Timestamp = None) -> dict: # type: ignore
    """
    Estimate a team's form over their last N matches.

    Parameters
    ----------
    team        : team name as it appears in results_clean.csv
    n           : number of matches to look back
    competitive : if True, exclude friendlies
    as_of       : if provided, only consider matches up to this date and use
                  historical ELO as the baseline instead of ELO_LOOKUP.
                  Pass as pd.Timestamp('YYYY-MM-DD') or a date string.

    Returns
    -------
    dict with keys:
        form_score   – net ELO delta over last N matches (positive = above expectation)
        matches_used – actual number of matches found
        record       – (wins, draws, losses)
        matches      – DataFrame of the individual matches with per-match contribution
    """
    if as_of is not None:
        as_of = pd.Timestamp(as_of)

    tm = TEAM_MATCHES.get(team)
    if tm is None:
        return {'form_score': 0.0, 'matches_used': 0, 'record': (0, 0, 0), 'matches': pd.DataFrame()}

    if as_of is not None:
        tm = tm[tm['date'] <= as_of]

    if competitive:
        tm = tm[~tm['tournament'].isin(FRIENDLY_TOURNAMENTS)]

    tm = tm.tail(n).copy()

    # ELO baseline: historical lookup if as_of given, otherwise WC2026 flat lookup
    if as_of is not None:
        r_team = get_elo_at_date(team, as_of)
    else:
        r_team = ELO_LOOKUP.get(team, 1000.0)

    contributions = []
    wins = draws = losses = 0

    for _, row in tm.iterrows():
        is_home = row['home_team'] == team
        opp     = row['away_team'] if is_home else row['home_team']
        I       = TOURNAMENT_WEIGHTS.get(row['tournament'], 1.0)

        if as_of is not None:
            r_opp = get_elo_at_date(opp, as_of)
        else:
            r_opp = ELO_LOOKUP.get(opp, 1000.0)

        we = expected_result(r_team, r_opp)

        h, a = row['home_score'], row['away_score']
        if h > a:   w = 1.0 if is_home else 0.0
        elif h < a: w = 0.0 if is_home else 1.0
        else:       w = 0.5

        contributions.append(round(I * (w - we), 4))

        if w == 1.0:   wins   += 1
        elif w == 0.5: draws  += 1
        else:          losses += 1

    tm = tm.copy()
    tm['elo_contribution'] = contributions

    return {
        'form_score':   round(sum(contributions), 4),
        'matches_used': len(tm),
        'record':       (wins, draws, losses),
        'matches':      tm[['date', 'home_team', 'away_team', 'home_score',
                             'away_score', 'tournament', 'elo_contribution']],
    }

# %% [markdown]
# ## Sanity Tests

# %%
# All matches form
form = get_form('Germany', n=10, competitive=False, as_of="2014-06-01") # type: ignore
print(f"Germany — last 10 matches")
print(f"  Form score : {form['form_score']:+.2f}")
print(f"  Record     : {form['record'][0]}W {form['record'][1]}D {form['record'][2]}L")
print()
form['matches']
# Out:
# Germany — last 10 matches
#   Form score : +1.19
#   Record     : 6W 4D 0L
#           date      home_team            away_team  home_score  away_score  \
# 868 2013-08-14        Germany             Paraguay           3           3
# 869 2013-09-06        Germany              Austria           3           0
# 870 2013-09-10  Faroe Islands              Germany           0           3
# 871 2013-10-11        Germany  Republic of Ireland           3           0
# 872 2013-10-15         Sweden              Germany           3           5
# 873 2013-11-15          Italy              Germany           1           1
# 874 2013-11-19        England              Germany           0           1
# 875 2014-03-05        Germany                Chile           1           0
# 876 2014-05-13        Germany               Poland           0           0
# 877 2014-06-01        Germany             Cameroon           2           2
#
#                        tournament  elo_contribution
# ...

# %%
# Competitive-only form
form_comp = get_form('England', n=15, competitive=True)
print(f"England — last 15 competitive matches")
print(f"  Form score : {form_comp['form_score']:+.2f}")
print(f"  Record     : {form_comp['record'][0]}W {form_comp['record'][1]}D {form_comp['record'][2]}L")
print()
form_comp['matches']
# Out:
# England — last 15 competitive matches
#   Form score : +1.52
#   Record     : 13W 0D 2L
#            date            home_team            away_team  home_score  \
# 1069 2024-07-14                Spain              England           2
# 1070 2024-09-07  Republic of Ireland              England           0
# 1071 2024-09-10              England              Finland           2
# 1072 2024-10-10              England               Greece           1
# 1073 2024-10-13              Finland              England           1
# 1074 2024-11-14               Greece              England           0
# 1075 2024-11-17              England  Republic of Ireland           5
# 1076 2025-03-21              England              Albania           2
# 1077 2025-03-24              England               Latvia           3
# 1078 2025-06-07              Andorra              England           0
# 1080 2025-09-06              England              Andorra           2
# ...

# %%
# Compare form across several teams
teams = ['Brazil', 'Argentina', 'France', 'England', 'Spain', 'Germany', 'Morocco', 'Japan']

rows = []
for t in teams:
    f_all  = get_form(t, n=10, competitive=False)
    f_comp = get_form(t, n=10, competitive=True)
    rows.append({
        'team':           t,
        'form_all':       f_all['form_score'],
        'form_comp':      f_comp['form_score'],
        'record_all':     f_all['record'],
        'record_comp':    f_comp['record'],
    })

pd.DataFrame(rows).sort_values('form_comp', ascending=False)
# Out:
#         team  form_all  form_comp record_all record_comp
# 6    Morocco    3.7932     5.5750  (7, 3, 0)   (8, 2, 0)
# 3    England    0.8263     3.3188  (7, 1, 2)  (10, 0, 0)
# 4      Spain    0.3853     0.6258  (7, 3, 0)   (6, 4, 0)
# 2     France    1.1935     0.6171  (8, 1, 1)   (7, 1, 2)
# 7      Japan    1.9811     0.2550  (7, 2, 1)   (7, 2, 1)
# 5    Germany    1.9624     0.1838  (9, 0, 1)   (6, 1, 3)
# 0     Brazil   -0.9264    -0.8079  (6, 1, 3)   (4, 3, 3)
# 1  Argentina   -0.5047    -1.1937  (8, 1, 1)   (6, 2, 2)

# %% [markdown]
# ----------
# # Finalizing Training Data

# %%
TRAINING_DIR = Path('training')
TRAINING_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ## Get Timestamps of World Cup Dates for Elo Pulls + Clean World Cup Matches CSV

# %%
WC_YEARS = {
    1998: pd.Timestamp('1998-06-09'),
    2002: pd.Timestamp('2002-05-30'),
    2006: pd.Timestamp('2006-06-08'),
    2010: pd.Timestamp('2010-06-10'),
    2014: pd.Timestamp('2014-06-11'),
    2018: pd.Timestamp('2018-06-13'),
    2022: pd.Timestamp('2022-11-19'),
}

# %%
wc_raw = pd.read_csv(Path('world_cup_matches') / 'matches_1930_2022.csv', parse_dates=['Date'])

KEEP_COLS = {
    'Year':          'year',
    'Date':          'date',
    'Round':         'round',
    'home_team':     'home_team',
    'away_team':     'away_team',
    'home_score':    'home_score',
    'away_score':    'away_score',
    'home_penalty':  'home_penalty',
    'away_penalty':  'away_penalty',
    'Notes':         'notes',
}

WC_NAME_FIX = {
    'FR Yugoslavia':        'Serbia',
    'Serbia and Montenegro':'Serbia',
    'Korea Republic':       'South Korea',
    'Korea DPR':            'North Korea',
    'IR Iran':              'Iran',
    'China PR':             'China',
    "Côte d'Ivoire":        'Ivory Coast',
    'Türkiye':              'Turkey',
}

wc_matches = (
    wc_raw[list(KEEP_COLS)]
    .rename(columns=KEEP_COLS)
    .query('year >= 1998')
    .sort_values(['year', 'date'])
    .reset_index(drop=True)
)

wc_matches['home_team'] = wc_matches['home_team'].replace(WC_NAME_FIX)
wc_matches['away_team'] = wc_matches['away_team'].replace(WC_NAME_FIX)

print(f'Matches 1998–2022: {len(wc_matches)}')
print(f'Years: {sorted(wc_matches["year"].unique())}')
# Out:
# Matches 1998–2022: 448
# Years: [np.int64(1998), np.int64(2002), np.int64(2006), np.int64(2010), np.int64(2014), np.int64(2018), np.int64(2022)]

# %% [markdown]
# ## Get Team Profiles for Each Year

# %%
def get_profiles(N):

    team_profiles = []
    seen = set()

    for _, m in wc_matches[wc_matches['year'] <= 2022].iterrows():
        snapshot = WC_YEARS[m['year']]
        
        for team in [m['home_team'], m['away_team']]:
            key = (team, m['year'])
            if key in seen:
                continue
            seen.add(key)
            
            team_profiles.append({
                'team':             team,
                'year':             m['year'],
                'elo':              get_elo_at_date(team, snapshot),
                'form':             get_form(team, n=N, competitive=False, as_of=snapshot)['form_score'],
                'competitive_form': get_form(team, n=N, competitive=True,  as_of=snapshot)['form_score'],
            })

    team_profiles = pd.DataFrame(team_profiles).sort_values(['year', 'elo']).reset_index(drop=True)

    return team_profiles

# %% [markdown]
# ### Build Training Data

# %%
profiles_5 = get_profiles(5).set_index(['team', 'year']) # type: ignore
profiles_10 = get_profiles(10).set_index(['team', 'year']) # type: ignore
profiles_15 = get_profiles(15).set_index(['team', 'year']) # type: ignore
profiles_20 = get_profiles(20).set_index(['team', 'year']) # type: ignore
profiles = [profiles_5, profiles_10, profiles_15, profiles_20]

TRAINING_COLS = [
        'year', 'date', 'round',
        'home_team', 'away_team',
        'home_score', 'away_score',
        'home_penalty', 'away_penalty',
        'home_elo', 'away_elo',
        'home_form', 'away_form',
        'home_comp_form', 'away_comp_form',
        'result',
    ]

def lookup(team, year, col, index):
    try:
        return profiles[index].loc[(team, year), col]
    except KeyError:
        return np.nan

# Result label from 90-min score: 1 = home win, 0 = draw, -1 = away win
def result_label(row):
    if row['home_score'] > row['away_score']:   return 1
    elif row['home_score'] < row['away_score']: return -1
    else:                                       return 0

for i in range(4):

    train_matches = wc_matches[wc_matches['year'] <= 2018].copy()

    for side, team_col in [('home', 'home_team'), ('away', 'away_team')]:
        train_matches[f'{side}_elo']       = train_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'elo', i),              axis=1)
        train_matches[f'{side}_form']      = train_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'form', i),             axis=1)
        train_matches[f'{side}_comp_form'] = train_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'competitive_form', i), axis=1)

    train_matches['result'] = train_matches.apply(result_label, axis=1)

    training_data = train_matches[TRAINING_COLS].reset_index(drop=True)

    output_path = MODEL_OUTPUT_DIR / f'training_data_{5 * (i + 1)}.csv'
    output_path.parent.mkdir(exist_ok=True)
    training_data.to_csv(output_path, index=False)

    print(f'Training rows : {len(training_data)}')
    print(f'Saved to      : {output_path}')
    print(f'\nResult distribution:')
    print(training_data['result'].value_counts().rename({1: 'Home win', 0: 'Draw', -1: 'Away win'}))
    print()
# Out:
# Training rows : 384
# Saved to      : model_data/training_data_5.csv
#
# Result distribution:
# result
# Home win    164
# Away win    128
# Draw         92
# Name: count, dtype: int64
#
# Training rows : 384
# Saved to      : model_data/training_data_10.csv
#
# Result distribution:
# result
# Home win    164
# Away win    128
# Draw         92
# Name: count, dtype: int64
#
# Training rows : 384
# Saved to      : model_data/training_data_15.csv
#
# Result distribution:
# result
# Home win    164
# Away win    128
# Draw         92
# Name: count, dtype: int64
#
# Training rows : 384
# Saved to      : model_data/training_data_20.csv
#
# Result distribution:
# result
# Home win    164
# Away win    128
# Draw         92
# Name: count, dtype: int64

# %% [markdown]
# ### Build Validation Data (same as training but for 2022)

# %%
for i in range(4):

    validation_matches = wc_matches[wc_matches['year'] == 2022].copy()

    for side, team_col in [('home', 'home_team'), ('away', 'away_team')]:
        validation_matches[f'{side}_elo']       = validation_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'elo', i),              axis=1)
        validation_matches[f'{side}_form']      = validation_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'form', i),             axis=1)
        validation_matches[f'{side}_comp_form'] = validation_matches.apply(lambda r, c=team_col: lookup(r[c], r['year'], 'competitive_form', i), axis=1)

    validation_matches['result'] = validation_matches.apply(result_label, axis=1)

    validation_data = validation_matches[TRAINING_COLS].reset_index(drop=True)

    output_path = MODEL_OUTPUT_DIR / f'validation_data_{5 * (i + 1)}.csv'
    output_path.parent.mkdir(exist_ok=True)
    validation_data.to_csv(output_path, index=False)

    print(f'Validation rows : {len(validation_data)}')
    print(f'Saved to      : {output_path}')
    print(f'\nResult distribution:')
    print(validation_data['result'].value_counts().rename({1: 'Home win', 0: 'Draw', -1: 'Away win'}))
    print()
# Out:
# Validation rows : 64
# Saved to      : model_data/validation_data_5.csv
#
# Result distribution:
# result
# Home win    29
# Away win    20
# Draw        15
# Name: count, dtype: int64
#
# Validation rows : 64
# Saved to      : model_data/validation_data_10.csv
#
# Result distribution:
# result
# Home win    29
# Away win    20
# Draw        15
# Name: count, dtype: int64
#
# Validation rows : 64
# Saved to      : model_data/validation_data_15.csv
#
# Result distribution:
# result
# Home win    29
# Away win    20
# Draw        15
# Name: count, dtype: int64
#
# Validation rows : 64
# Saved to      : model_data/validation_data_20.csv
#
# Result distribution:
# result
# Home win    29
# Away win    20
# Draw        15
# Name: count, dtype: int64

# %% [markdown]
# ## Build 2026 Data

# %%
wc2026_elo = pd.read_csv(OUTPUT_DIR / 'wc2026_elo_clean.csv')
WC2026_TEAMS = wc2026_elo['team'].tolist()

def get_2026_profiles(N):
    rows = []
    for team in WC2026_TEAMS:
        rows.append({
            'team':             team,
            'elo':              ELO_LOOKUP.get(team, 1000.0),
            'form':             get_form(team, n=N, competitive=False)['form_score'],
            'comp_form': get_form(team, n=N, competitive=True)['form_score'],
        })
    return pd.DataFrame(rows).sort_values('elo', ascending=False).reset_index(drop=True)

profiles_2026_10 = get_2026_profiles(10)
profiles_2026_20 = get_2026_profiles(20)

profiles_2026_10.to_csv(MODEL_OUTPUT_DIR / 'profiles_2026_10.csv', index=False)
profiles_2026_20.to_csv(MODEL_OUTPUT_DIR / 'profiles_2026_20.csv', index=False)

print(f'2026 teams : {len(profiles_2026_10)}')
print()
profiles_2026_10
# Out:
# 2026 teams : 48
#                       team     elo    form  comp_form
# 0                    Spain  2171.0  0.3853     0.6258
# 1                Argentina  2113.0 -0.5047    -1.1937
# 2                   France  2062.0  1.1935     0.6171
# 3                  England  2042.0  0.8263     3.3188
# 4                 Colombia  1998.0  1.2584    -5.0533
# 5                   Brazil  1979.0 -0.9264    -0.8079
# 6                 Portugal  1976.0 -0.0402    -0.1443
# 7              Netherlands  1959.0 -0.0980     1.0020
# 8                  Ecuador  1933.0  1.5777     3.0464
# 9                  Croatia  1933.0  0.6216     2.0336
# 10                  Norway  1922.0  1.6230     4.7171
# 11                 Germany  1910.0  1.9624     0.1838
# 12             Switzerland  1897.0  1.8982     0.6218
# 13                 Uruguay  1890.0 -0.3509    -1.2065
# 14                  Turkey  1880.0  4.4670     4.8678
# 15                   Japan  1878.0  1.9811     0.2550
# ...

# %%
fixtures = pd.read_csv(Path('world_cup_matches') / 'wc2026_group_fixtures.csv')

for n, profiles_2026 in [(10, profiles_2026_10), (20, profiles_2026_20)]:
    p = profiles_2026.set_index('team')

    def attach(side, team_col):
        fixtures[f'{side}_elo']       = fixtures[team_col].map(p['elo'])
        fixtures[f'{side}_form']      = fixtures[team_col].map(p['form'])
        fixtures[f'{side}_comp_form'] = fixtures[team_col].map(p['comp_form'])

    attach('home', 'home_team')
    attach('away', 'away_team')

    fixtures['elo_diff']       = fixtures['home_elo']       - fixtures['away_elo']
    fixtures['form_diff']      = fixtures['home_form']       - fixtures['away_form']
    fixtures['comp_form_diff'] = fixtures['home_comp_form']  - fixtures['away_comp_form']

    out = MODEL_OUTPUT_DIR / f'fixtures_2026_n{n}.csv'
    fixtures.to_csv(out, index=False)
    print(f'Saved {out}')

print()
fixtures.head(10)
# Out:
# Saved model_data/fixtures_2026_n10.csv
# Saved model_data/fixtures_2026_n20.csv
#   group       home_team               away_team  home_elo  home_form  \
# 0     A          Mexico             South Korea    1835.0     5.3584
# 1     A          Mexico          Czech Republic    1835.0     5.3584
# 2     A          Mexico            South Africa    1835.0     5.3584
# 3     A     South Korea          Czech Republic    1784.0     2.3343
# 4     A     South Korea            South Africa    1784.0     2.3343
# 5     A  Czech Republic            South Africa    1731.0     1.9619
# 6     B          Canada             Switzerland    1802.0     1.4751
# 7     B          Canada  Bosnia and Herzegovina    1802.0     1.4751
# 8     B          Canada                   Qatar    1802.0     1.4751
# 9     B     Switzerland  Bosnia and Herzegovina    1897.0    -0.1630
#
#    home_comp_form  away_elo  away_form  away_comp_form  elo_diff  form_diff  \
# ...
